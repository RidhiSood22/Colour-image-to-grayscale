# %% [markdown]
# <a href="https://colab.research.google.com/github/RidhiSood22/Colour-image-to-grayscale/blob/main/Colour_image_to_grayscale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# !pip install opencv-contrib-python
# !pip install numpy

# %%
import cv2
from google.colab.patches import cv2_imshow

# Ensure the path to your image is correct
img_path = '/content/download.jpeg'
# Load the image, handling potential errors
img = cv2.imread(img_path)

if img is None:
    print("Error: Could not read the image. Check the file path and format.")
else:
    # Convert the image to grayscale
    gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Display the grayscale image
    cv2_imshow(gray_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=215x148>
